# %%
trans_rdd = spark.read.csv('/Workspace/Users/selvakumar.ravindran@gmail.com/Datafiles/customers-1000000.csv', header=True, inferSchema=True)

trans_rdd.select("Index", "First Name","Last Name","Company").show(100)

# %%
trans_rdd.show(5)

# %%
# %sql
CREATE TABLE customer AS
SELECT Index,`Customer Id` as Customer_Id,`First Name` as First_Name,`Last Name` as Last_Name,Company,City,Country,`Phone 1` as Phone_1,`Phone 2` as Phone_2,Email,`Subscription Date` as Subscription_Date,Website FROM read_files('/Workspace/Users/selvakumar.ravindran@gmail.com/Datafiles/customers-1000000.csv',format => 'csv', pathGlobFilter => '*.csv', header => 'true')

# %%
# %sql
select * from customer limit 10

# %%
# %sql
describe customer
